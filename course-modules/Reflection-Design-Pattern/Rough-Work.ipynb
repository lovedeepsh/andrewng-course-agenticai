# %%
import pandas as pd
import numpy as np

print("Jupyter is working!")
# Out:
# Jupyter is working!

# %%
import re
import json
import utils

# %%
df = pd.read_csv('coffee_sales.csv')
df.sample(n=2)
# Out:
#             date   time cash_type                 card  price coffee_name
# 2142  2024-10-29  09:56      card  ANON-0000-0000-0831  2.596     Cortado
# 2466  2024-12-03  14:59      card  ANON-0000-0000-0685  3.576  Cappuccino

# %%
df = pd.read_csv('coffee_sales.csv')
df["date"] = pd.to_datetime(df["date"])
df["price"] = pd.to_numeric(df["price"])
df = df.assign(quarter=df["date"].dt.quarter)
df = df.assign(month=df["date"].dt.month)
df = df.assign(year=df["date"].dt.year)
df = df.assign(year=df["date"].dt.day_name())
df = df.assign(year=df["date"].dt.strftime("%Y-%m"))
#df.sample(n=5)
#df.sample(n=5, random_state=42)
df.sample(frac=0.1)
# Out:
#            date   time cash_type                 card  price  \
# 864  2024-06-24  17:52      card  ANON-0000-0000-0203  3.772
# 908  2024-07-03  09:10      card  ANON-0000-0000-0270  3.282
# 3306 2025-02-28  08:32      card  ANON-0000-0000-1110  2.596
# 3607 2025-03-21  11:55      card  ANON-0000-0000-1275  3.576
# 326  2024-04-19  09:01      card  ANON-0000-0000-0040  3.380
# ...         ...    ...       ...                  ...    ...
# 1920 2024-10-14  07:26      card  ANON-0000-0000-0440  3.576
# 537  2024-05-20  12:26      cash                  NaN  2.900
# 1744 2024-09-30  14:27      card  ANON-0000-0000-0694  2.596
# 3324 2025-03-01  17:52      card  ANON-0000-0000-1258  2.596
# 1415 2024-09-02  06:24      card  ANON-0000-0000-0425  3.282
#
#               coffee_name  quarter  month     year
# 864            Cappuccino        2      6  2024-06
# 908   Americano with Milk        3      7  2024-07
# 3306            Americano        1      2  2025-02
# 3607                Latte        1      3  2025-03
# 326   Americano with Milk        2      4  2024-04
# ...                   ...      ...    ...      ...
# 1920                Latte        4     10  2024-10
# 537             Americano        2      5  2024-05
# 1744              Cortado        3      9  2024-09
# 3324            Americano        1      3  2025-03
# 1415                Latte        3      9  2024-09
#
# [364 rows x 9 columns]

# %%
def load_and_prepare_data(file_path: str):
    df = pd.read_csv(file_path)
    df["date"] = pd.to_datetime(df["date"])
    df["price"] = pd.to_numeric(df["price"])
    df = df.assign(quarter=df["date"].dt.quarter)
    df = df.assign(month=df["date"].dt.month)
    df = df.assign(year=df["date"].dt.year)
    #pd.DataFrame
    return df

# %%
load_and_prepare_data('coffee_sales.csv')
# Out:
#            date   time cash_type                 card  price    coffee_name  \
# 0    2024-03-01  06:14      card  ANON-0000-0000-0001  3.870          Latte
# 1    2024-03-01  11:10      card  ANON-0000-0000-0002  3.870  Hot Chocolate
# 2    2024-03-01  11:19      card  ANON-0000-0000-0002  3.870  Hot Chocolate
# 3    2024-03-01  11:37      card  ANON-0000-0000-0003  2.890      Americano
# 4    2024-03-01  12:56      card  ANON-0000-0000-0004  3.870          Latte
# ...         ...    ...       ...                  ...    ...            ...
# 3631 2025-03-23  11:17      card  ANON-0000-0000-1158  3.576     Cappuccino
# 3632 2025-03-23  13:07      card  ANON-0000-0000-1315  3.576          Cocoa
# 3633 2025-03-23  13:51      card  ANON-0000-0000-1315  3.576          Cocoa
# 3634 2025-03-23  15:09      card  ANON-0000-0000-1316  2.596      Americano
# 3635 2025-03-23  17:50      card  ANON-0000-0000-1275  3.576          Latte
#
#       quarter  month  year
# 0           1      3  2024
# 1           1      3  2024
# 2           1      3  2024
# 3           1      3  2024
# 4           1      3  2024
# ...       ...    ...   ...
# 3631        1      3  2025
# 3632        1      3  2025
# 3633        1      3  2025
# 3634        1      3  2025
# 3635        1      3  2025
#
# [3636 rows x 9 columns]

# %%
#df.to_html()
#df.to_html(index=False)
#df.to_html(border=0)
html_table = df.to_html(max_rows=5)

# %%
display(HTML(html_table))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 display(HTML(html_table))
#
# NameError: name 'HTML' is not defined

# %%
from IPython.display import display, HTML
display(HTML(html_table))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date</th>
#       <th>time</th>
#       <th>cash_type</th>
#       <th>card</th>
#       <th>price</th>
#       <th>coffee_name</th>
#       <th>quarter</th>
#       <th>month</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2024-03-01</td>
#       <td>06:14</td>
#       <td>card</td>
#       <td>ANON-0000-0000-0001</td>
#       <td>3.870</td>
#       <td>Latte</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2024-03</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2024-03-01</td>
#       <td>11:10</td>
#       <td>card</td>
#       <td>ANON-0000-0000-0002</td>
#       <td>3.870</td>
#       <td>Hot Chocolate</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2024-03</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>3634</th>
#       <td>2025-03-23</td>
#       <td>15:09</td>
#       <td>card</td>
#       <td>ANON-0000-0000-1316</td>
#       <td>2.596</td>
#       <td>Americano</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2025-03</td>
#     </tr>
#     <tr>
#       <th>3635</th>
#       <td>2025-03-23</td>
#       <td>17:50</td>
#       <td>card</td>
#       <td>ANON-0000-0000-1275</td>
#       <td>3.576</td>
#       <td>Latte</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2025-03</td>
#     </tr>
#   </tbody>
# </table>

# %%
def print_html(df, title=None, border=0, max_rows=None, index=False):
    html_table = df.to_html(
    border=border,
    max_rows=max_rows,
    index=index
    )
    heading = HTML(f"<h3>{title}</h3>")
    if title is not None:
        display(heading)
    #return display(HTML(html_table))
    display(HTML(html_table))

# %%
print_html(df, title="I am hero", max_rows=5)
# Out:
# <h3>I am hero</h3>
# <table class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>date</th>
#       <th>time</th>
#       <th>cash_type</th>
#       <th>card</th>
#       <th>price</th>
#       <th>coffee_name</th>
#       <th>quarter</th>
#       <th>month</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2024-03-01</td>
#       <td>06:14</td>
#       <td>card</td>
#       <td>ANON-0000-0000-0001</td>
#       <td>3.870</td>
#       <td>Latte</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2024-03</td>
#     </tr>
#     <tr>
#       <td>2024-03-01</td>
#       <td>11:10</td>
#       <td>card</td>
#       <td>ANON-0000-0000-0002</td>
#       <td>3.870</td>
#       <td>Hot Chocolate</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2024-03</td>
#     </tr>
#     <tr>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <td>2025-03-23</td>
#       <td>15:09</td>
#       <td>card</td>
#       <td>ANON-0000-0000-1316</td>
#       <td>2.596</td>
#       <td>Americano</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2025-03</td>
#     </tr>
#     <tr>
#       <td>2025-03-23</td>
#       <td>17:50</td>
#       <td>card</td>
#       <td>ANON-0000-0000-1275</td>
#       <td>3.576</td>
#       <td>Latte</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2025-03</td>
#     </tr>
#   </tbody>
# </table>
