# %%
import pandas as pd
import numpy as np

print("Jupyter is working!")
# Out:
# Jupyter is working!

# %%
import re
import json
import utils

# %%
df = pd.read_csv('coffee_sales.csv')
df.sample(n=2)
# Out:
#             date   time cash_type                 card  price coffee_name
# 1732  2024-09-29  15:45      card  ANON-0000-0000-0688  3.576       Latte
# 1788  2024-10-04  16:14      card  ANON-0000-0000-0650  2.596     Cortado

# %%
df = pd.read_csv('coffee_sales.csv')
df["date"] = pd.to_datetime(df["date"])
df["price"] = pd.to_numeric(df["price"])
df = df.assign(quarter=df["date"].dt.quarter)
df = df.assign(month=df["date"].dt.month)
df = df.assign(year=df["date"].dt.year)
df = df.assign(year=df["date"].dt.day_name())
df = df.assign(year=df["date"].dt.strftime("%Y-%m"))
#df.sample(n=5)
#df.sample(n=5, random_state=42)
df.sample(frac=0.1)
# Out:
#            date   time cash_type                 card  price  \
# 2068 2024-10-24  07:41      card  ANON-0000-0000-0809  3.576
# 1397 2024-08-30  11:35      card  ANON-0000-0000-0554  2.792
# 2618 2024-12-23  14:33      card  ANON-0000-0000-1036  3.086
# 1152 2024-08-03  06:44      card  ANON-0000-0000-0401  2.792
# 1429 2024-09-03  09:53      card  ANON-0000-0000-0572  3.282
# ...         ...    ...       ...                  ...    ...
# 1977 2024-10-17  14:09      card  ANON-0000-0000-0777  3.576
# 2198 2024-11-03  13:01      card  ANON-0000-0000-0851  3.086
# 793  2024-06-16  08:02      card  ANON-0000-0000-0303  3.772
# 587  2024-05-24  16:21      card  ANON-0000-0000-0210  3.282
# 3169 2025-02-19  13:54      card  ANON-0000-0000-1217  3.086
#
#               coffee_name  quarter  month     year
# 2068           Cappuccino        4     10  2024-10
# 1397  Americano with Milk        3      8  2024-08
# 2618  Americano with Milk        4     12  2024-12
# 1152  Americano with Milk        3      8  2024-08
# 1429                Cocoa        3      9  2024-09
# ...                   ...      ...    ...      ...
# 1977        Hot Chocolate        4     10  2024-10
# 2198  Americano with Milk        4     11  2024-11
# 793         Hot Chocolate        2      6  2024-06
# 587   Americano with Milk        2      5  2024-05
# 3169  Americano with Milk        1      2  2025-02
#
# [364 rows x 9 columns]

# %%
def load_and_prepare_data(file_path: str):
    df = pd.read_csv(file_path)
    df["date"] = pd.to_datetime(df["date"])
    df["price"] = pd.to_numeric(df["price"])
    df = df.assign(quarter=df["date"].dt.quarter)
    df = df.assign(month=df["date"].dt.month)
    df = df.assign(year=df["date"].dt.year)
    #pd.DataFrame
    return df

# %%
load_and_prepare_data('coffee_sales.csv')
# Out:
#            date   time cash_type                 card  price    coffee_name  \
# 0    2024-03-01  06:14      card  ANON-0000-0000-0001  3.870          Latte
# 1    2024-03-01  11:10      card  ANON-0000-0000-0002  3.870  Hot Chocolate
# 2    2024-03-01  11:19      card  ANON-0000-0000-0002  3.870  Hot Chocolate
# 3    2024-03-01  11:37      card  ANON-0000-0000-0003  2.890      Americano
# 4    2024-03-01  12:56      card  ANON-0000-0000-0004  3.870          Latte
# ...         ...    ...       ...                  ...    ...            ...
# 3631 2025-03-23  11:17      card  ANON-0000-0000-1158  3.576     Cappuccino
# 3632 2025-03-23  13:07      card  ANON-0000-0000-1315  3.576          Cocoa
# 3633 2025-03-23  13:51      card  ANON-0000-0000-1315  3.576          Cocoa
# 3634 2025-03-23  15:09      card  ANON-0000-0000-1316  2.596      Americano
# 3635 2025-03-23  17:50      card  ANON-0000-0000-1275  3.576          Latte
#
#       quarter  month  year
# 0           1      3  2024
# 1           1      3  2024
# 2           1      3  2024
# 3           1      3  2024
# 4           1      3  2024
# ...       ...    ...   ...
# 3631        1      3  2025
# 3632        1      3  2025
# 3633        1      3  2025
# 3634        1      3  2025
# 3635        1      3  2025
#
# [3636 rows x 9 columns]

# %%
#df.to_html()
#df.to_html(index=False)
#df.to_html(border=0)
html_table = df.to_html(max_rows=5)

# %%
display(HTML(html_table))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 display(HTML(html_table))
#
# NameError: name 'HTML' is not defined

# %%
from IPython.display import display, HTML
display(HTML(html_table))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date</th>
#       <th>time</th>
#       <th>cash_type</th>
#       <th>card</th>
#       <th>price</th>
#       <th>coffee_name</th>
#       <th>quarter</th>
#       <th>month</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2024-03-01</td>
#       <td>06:14</td>
#       <td>card</td>
#       <td>ANON-0000-0000-0001</td>
#       <td>3.870</td>
#       <td>Latte</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2024-03</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2024-03-01</td>
#       <td>11:10</td>
#       <td>card</td>
#       <td>ANON-0000-0000-0002</td>
#       <td>3.870</td>
#       <td>Hot Chocolate</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2024-03</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>3634</th>
#       <td>2025-03-23</td>
#       <td>15:09</td>
#       <td>card</td>
#       <td>ANON-0000-0000-1316</td>
#       <td>2.596</td>
#       <td>Americano</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2025-03</td>
#     </tr>
#     <tr>
#       <th>3635</th>
#       <td>2025-03-23</td>
#       <td>17:50</td>
#       <td>card</td>
#       <td>ANON-0000-0000-1275</td>
#       <td>3.576</td>
#       <td>Latte</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2025-03</td>
#     </tr>
#   </tbody>
# </table>

# %%
def print_html(df, title=None, border=0, max_rows=None, index=False):
    html_table = df.to_html(
    border=border,
    max_rows=max_rows,
    index=index
    )
    heading = HTML(f"<h3>{title}</h3>")
    if title is not None:
        display(heading)
    #return display(HTML(html_table))
    display(HTML(html_table))

# %%
print_html(df, title="I am hero", max_rows=5)
# Out:
# <h3>I am hero</h3>
# <table class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>date</th>
#       <th>time</th>
#       <th>cash_type</th>
#       <th>card</th>
#       <th>price</th>
#       <th>coffee_name</th>
#       <th>quarter</th>
#       <th>month</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2024-03-01</td>
#       <td>06:14</td>
#       <td>card</td>
#       <td>ANON-0000-0000-0001</td>
#       <td>3.870</td>
#       <td>Latte</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2024-03</td>
#     </tr>
#     <tr>
#       <td>2024-03-01</td>
#       <td>11:10</td>
#       <td>card</td>
#       <td>ANON-0000-0000-0002</td>
#       <td>3.870</td>
#       <td>Hot Chocolate</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2024-03</td>
#     </tr>
#     <tr>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <td>2025-03-23</td>
#       <td>15:09</td>
#       <td>card</td>
#       <td>ANON-0000-0000-1316</td>
#       <td>2.596</td>
#       <td>Americano</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2025-03</td>
#     </tr>
#     <tr>
#       <td>2025-03-23</td>
#       <td>17:50</td>
#       <td>card</td>
#       <td>ANON-0000-0000-1275</td>
#       <td>3.576</td>
#       <td>Latte</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2025-03</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib
from openai import OpenAI
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
client = OpenAI()

# %%
schema = """
coffee_sales.csv columns:
- date: sale date
- time: sale time
- cash_type: cash or card
- card: anonymized card id
- price: sale amount / revenue
- coffee_name: coffee product name
- quarter: quarter number
- month: month number
- year: year
"""

# %%
question = "Create a plot comparing Q1 coffee sales in 2024 and 2025 using the data in coffee_sales.csv."

# %%
prompt = f"""
You are a Python data analyst.

Dataset schema:
{schema}

User question:
{question}

Rules:
- Use pandas and matplotlib only.
- Read data from coffee_sales.csv.
- Return only Python code inside <execute_python> and </execute_python> tags.
- Do not explain anything.
"""

# %%
response = client.responses.create(
    model="gpt-4.1-mini",
    input=prompt,
    temperature=0
)

# %%
print(response.output_text)
# Out:
# <execute_python>
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Load data
# df = pd.read_csv('coffee_sales.csv')
#
# # Filter data for Q1 in 2024 and 2025
# df_q1 = df[(df['quarter'] == 1) & (df['year'].isin([2024, 2025]))]
#
# # Aggregate sales by coffee_name and year
# sales_summary = df_q1.groupby(['year', 'coffee_name'])['price'].sum().unstack()
#
# # Plot
# sales_summary.plot(kind='bar', figsize=(12, 6))
# plt.title('Q1 Coffee Sales Comparison: 2024 vs 2025')
# plt.xlabel('Coffee Name')
# plt.ylabel('Total Sales')
# plt.xticks(rotation=45)
# plt.legend(title='Year')
# plt.tight_layout()
# plt.show()
# </execute_python>
